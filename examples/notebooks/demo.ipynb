# %%
using NamedTrajectories

# %%
# define number of timesteps and timestep
T = 10
dt = 0.1
# Out:
# 0.1

# %%
# build named tuple of components and data matrices
components = (
    x = rand(3, T),
    u = rand(2, T),
)
# Out:
# (x = [0.7901630383989389 0.48963348031982423 … 0.8699219794167143 0.08151116486693522; 0.15584403767038624 0.780824350516572 … 0.9847718529131269 0.23613524252730878; 0.3838019782844674 0.11696811293518972 … 0.9522739974084595 0.08536095305441194], u = [0.3234624216192975 0.8252813716618558 … 0.6464624381526468 0.5667427196395095; 0.829717217397343 0.10159189711742023 … 0.778873813148502 0.5272465405779992])

# %%
# build trajectory
traj = NamedTrajectory(components; timestep=dt, controls=:u)
# Out:
# NamedTrajectory([0.7901630383989389 0.48963348031982423 … 0.8699219794167143 0.08151116486693522; 0.15584403767038624 0.780824350516572 … 0.9847718529131269 0.23613524252730878; … ; 0.3234624216192975 0.8252813716618558 … 0.6464624381526468 0.5667427196395095; 0.829717217397343 0.10159189711742023 … 0.778873813148502 0.5272465405779992], [0.7901630383989389, 0.15584403767038624, 0.3838019782844674, 0.3234624216192975, 0.829717217397343, 0.48963348031982423, 0.780824350516572, 0.11696811293518972, 0.8252813716618558, 0.10159189711742023  …  0.8699219794167143, 0.9847718529131269, 0.9522739974084595, 0.6464624381526468, 0.778873813148502, 0.08151116486693522, 0.23613524252730878, 0.08536095305441194, 0.5667427196395095, 0.5272465405779992], 10, 0.1, false, 5, (x = 3, u = 2, states = 3, controls = 2), NamedTuple(), NamedTuple(), NamedTuple(), NamedTuple(), (x = 1:3, u = 4:5, states = [1, 2, 3], controls = [4, 5]), (:x, :u), (:u,))

# %%
# access data by name
traj.x # returns 3x10 matrix of x data
# Out:
# 3×10 Matrix{Float64}:
#  0.790163  0.489633  0.786159   0.107424  …  0.57721   0.869922  0.0815112
#  0.155844  0.780824  0.733495   0.36143      0.684962  0.984772  0.236135
#  0.383802  0.116968  0.0829928  0.988643     0.875653  0.952274  0.085361

# %%
traj.u # returns 2x10 matrix of u data
# Out:
# 2×10 Matrix{Float64}:
#  0.323462  0.825281  0.695487  0.82539   …  0.292036  0.646462  0.566743
#  0.829717  0.101592  0.33319   0.234145     0.523142  0.778874  0.527247

# %%
z1 = traj[1] # returns TimeSlice with x and u data
# Out:
# TimeSlice(1, [0.7901630383989389, 0.15584403767038624, 0.3838019782844674, 0.3234624216192975, 0.829717217397343], (x = 1:3, u = 4:5, states = [1, 2, 3], controls = [4, 5]), (:x, :u), (:u,))

# %%
z1.x # returns 3x1 matrix of x data
# Out:
# 3-element Vector{Float64}:
#  0.7901630383989389
#  0.15584403767038624
#  0.3838019782844674

# %%
z1.u # returns 2x1 matrix of u data
# Out:
# 2-element Vector{Float64}:
#  0.3234624216192975
#  0.829717217397343

# %%
z1.x # returns 3x1 matrix of x data
z1.u # returns 2x1 matrix of u data
# Out:
# 2-element Vector{Float64}:
#  0.3234624216192975
#  0.829717217397343

# %%
traj.data # returns data as 5x10 matrix
# Out:
# 5×10 reshape(view(::Vector{Float64}, :), 5, 10) with eltype Float64:
#  0.790163  0.489633  0.786159   0.107424  …  0.57721   0.869922  0.0815112
#  0.155844  0.780824  0.733495   0.36143      0.684962  0.984772  0.236135
#  0.383802  0.116968  0.0829928  0.988643     0.875653  0.952274  0.085361
#  0.323462  0.825281  0.695487   0.82539      0.292036  0.646462  0.566743
#  0.829717  0.101592  0.33319    0.234145     0.523142  0.778874  0.527247

# %%
traj.names # returns names as tuple (:x, :u)
# Out:
# (:x, :u)

# %%
plot(traj)

# %%
plot("./demo.png", traj)
# Out:
# CairoMakie.Screen{IMAGE}
