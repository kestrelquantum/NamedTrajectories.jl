# %%
using NamedTrajectories

# %%
# define number of timesteps and timestep
T = 10
dt = 0.1
# Out:
# 0.1

# %%
# build named tuple of components and data matrices
components = (
    x = rand(3, T),
    u = rand(2, T),
)
# Out:
# (x = [0.8466335986583172 0.7391699456568966 … 0.15630468015288534 0.3454241610044124; 0.4233134605179105 0.021984123439704684 … 0.9872551449716381 0.6319988847867036; 0.46224512699542675 0.15641427444079536 … 0.0970902601651783 0.9085317784985485], u = [0.4339954875416975 0.7027158659996645 … 0.7729838696612231 0.3568883306123789; 0.19779245339081963 0.6443422720463627 … 0.8652695724629146 0.21429383415020042])

# %%
# build trajectory
traj = NamedTrajectory(components; dt=dt, controls=:u)
# Out:
# NamedTrajectory([0.8466335986583172 0.7391699456568966 … 0.15630468015288534 0.3454241610044124; 0.4233134605179105 0.021984123439704684 … 0.9872551449716381 0.6319988847867036; … ; 0.4339954875416975 0.7027158659996645 … 0.7729838696612231 0.3568883306123789; 0.19779245339081963 0.6443422720463627 … 0.8652695724629146 0.21429383415020042], [0.8466335986583172, 0.4233134605179105, 0.46224512699542675, 0.4339954875416975, 0.19779245339081963, 0.7391699456568966, 0.021984123439704684, 0.15641427444079536, 0.7027158659996645, 0.6443422720463627  …  0.15630468015288534, 0.9872551449716381, 0.0970902601651783, 0.7729838696612231, 0.8652695724629146, 0.3454241610044124, 0.6319988847867036, 0.9085317784985485, 0.3568883306123789, 0.21429383415020042], 10, 0.1, false, 5, (x = 3, u = 2, states = 3, controls = 2), NamedTuple(), NamedTuple(), NamedTuple(), NamedTuple(), (x = 1:3, u = 4:5, states = [1, 2, 3], controls = [4, 5]), (:x, :u), (:u,))

# %%
# access data by name
traj.x # returns 3x10 matrix of x data
# Out:
# 3×10 Matrix{Float64}:
#  0.846634  0.73917    0.522791   …  0.00589198  0.156305   0.345424
#  0.423313  0.0219841  0.182519      0.778235    0.987255   0.631999
#  0.462245  0.156414   0.0955073     0.45268     0.0970903  0.908532

# %%
traj.u # returns 2x10 matrix of u data
# Out:
# 2×10 Matrix{Float64}:
#  0.433995  0.702716  0.231259  0.31746   …  0.295144  0.772984  0.356888
#  0.197792  0.644342  0.972087  0.742353     0.81192   0.86527   0.214294

# %%
z1 = traj[1] # returns TimeSlice with x and u data
# Out:
# TimeSlice(1, [0.8466335986583172, 0.4233134605179105, 0.46224512699542675, 0.4339954875416975, 0.19779245339081963], (x = 1:3, u = 4:5, states = [1, 2, 3], controls = [4, 5]), (:x, :u), (:u,))

# %%
z1.x # returns 3x1 matrix of x data
# Out:
# 3-element Vector{Float64}:
#  0.8466335986583172
#  0.4233134605179105
#  0.46224512699542675

# %%
z1.u # returns 2x1 matrix of u data
# Out:
# 2-element Vector{Float64}:
#  0.4339954875416975
#  0.19779245339081963

# %%
z1.x # returns 3x1 matrix of x data
z1.u # returns 2x1 matrix of u data

# %%
traj.data # returns data as 5x10 matrix
# Out:
# 5×10 reshape(view(::Vector{Float64}, :), 5, 10) with eltype Float64:
#  0.846634  0.73917    0.522791   …  0.00589198  0.156305   0.345424
#  0.423313  0.0219841  0.182519      0.778235    0.987255   0.631999
#  0.462245  0.156414   0.0955073     0.45268     0.0970903  0.908532
#  0.433995  0.702716   0.231259      0.295144    0.772984   0.356888
#  0.197792  0.644342   0.972087      0.81192     0.86527    0.214294

# %%
traj.names # returns names as tuple (:x, :u)
# Out:
# (:x, :u)

# %%
plot(traj)

# %%
plot("./demo.png", traj)
# Out:
# CairoMakie.Screen{IMAGE}
